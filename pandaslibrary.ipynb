# %%
# !pip install pandas

# %%
# !pip install numpy

# %%
import pandas as pd 
   
df = pd.DataFrame() 
print(df)
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks'] 
  
df = pd.DataFrame(lst) 
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
import pandas as pd 
import numpy as np

s = pd.Series() 
print("Pandas Series: ", s) 
data = np.array(['g', 'e', 'e', 'k', 's']) 
  
s = pd.Series(data) 
print("Pandas Series:\n", s)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
import pandas as pd

0\0]//
odf = pd.read_csv(r"C:\Users\Sharik\Desktop\pda.2\data.csv")
print(df.head())
# Out:
#    Unnamed: 0   name  age     city category  sales  a   b
# 0           0   John   25    Delhi        A    200  5  10
# 1           1   Riya   22   Mumbai        B    120  2   3
# 2           2   Aman   30     Pune        A    250  7   8
# 3           3   Neha   27  Kolkata        C    300  4   6
# 4           4  Arjun   35   Jaipur        B    200  1   9

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Sharik\Desktop\pda.2\data.csv")
print(df.head())
# Out:
#    Unnamed: 0   name  age     city category  sales  a   b
# 0           0   John   25    Delhi        A    200  5  10
# 1           1   Riya   22   Mumbai        B    120  2   3
# 2           2   Aman   30     Pune        A    250  7   8
# 3           3   Neha   27  Kolkata        C    300  4   6
# 4           4  Arjun   35   Jaipur        B    200  1   9

# %%
import pandas as pd 
import numpy as np

s = pd.Series() 
print("Pandas Series: ", s) 
data = np.array(['g', 'e', 'e', 'k', 's']) 
  
s = pd.Series(data) 
print("Pandas Series:\n", s)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
import pandas as pd 
   
df = pd.DataFrame() 
print(df)
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks'] 
  
df = pd.DataFrame(lst) 
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7 non-null      object
# dtypes: object(1)
# memory usage: 188.0+ bytes
# None

# %%
print(df.isnull().sum())
df = df.fillna(0)
# Out:
# 0    0
# dtype: int64

# %%
import pandas as pd 
s = pd.Series([10, 20, 30, 40])
s = pd.Series([85, 90, 78], index=["A", "B", "C"])
s[0]        
# Access first element 
s["A"]     # Access by label
s.mean(), s.max(), s.min()
# Out:
# C:\Users\Sharik\AppData\Local\Temp\ipykernel_19304\3567455865.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[0]
# (np.float64(84.33333333333333), 90, 78)

# %%
data = { 
"Name": ["Amit", "Riya", "Karan"], 
"Marks": [85, 90, 78] 
} 
df = pd.DataFrame(data)
data = { 
"Name": ["Amit", "Riya", "Karan"], 
"Marks": [85, 90, 78] 
} 
df = pd.DataFrame(data)
df["Name"]
df.loc[0] 
df.iloc[1]
df["Grade"] = ["A", "A+", "B"]
df.drop("Grade", axis=1)[df["Marks"] > 80]
df[df["Marks"] > 80]
df.describe()
# Out:
#            Marks
# count   3.000000
# mean   84.333333
# std     6.027714
# min    78.000000
# 25%    81.500000
# 50%    85.000000
# 75%    87.500000
# max    90.000000
